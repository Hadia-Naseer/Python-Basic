# %% [markdown]
# # **Python String Methods Practice**
# Please clean and preprocess a given paragraph using only Python string methods. You are NOT allowed to use built-in functions like regex or NLTK stopword removal.

# %% [markdown]
# ## **Instructions:**
# Perform the following steps on the given paragraph using only string methods:
#
# 1. **Remove Punctuation & Symbols** (e.g., `, . ! ? @ # $ % ^ & * ( ) - _ = + [ ] { } ; : ' " < > / \ |`)
# 2. **Remove Stopwords** (e.g., *is, am, are, the, a, an, in, on, of, and, to, for, with, etc.*)
# 3. **Remove Frequent Words** (Identify and remove most repeated words)
# 4. **Remove Whitespaces**
# 5. **Remove Digits** (0-9)
# 6. **Convert to Lowercase** (convert whole paragraphs into lower case)
# 7. **Tokenize the Text (Split into Words)**
#
# **You must only use Python string methods like `.replace()`, `.split()`, `.count()`, `.isdigit()`, etc.**
#
# for more methods, you can check this link: [https://docs.python.org/3/library/stdtypes.html#string-methods]

# %%
#Given Paragraph:

paragraph = """Hey! @Ali123, how r u? I hope u r doing well in ur exams.        The results r out on 25th & everyone is excited!!! 
Plz, check ur email & confirm ur attendance for the event. C u there!"""

# %%
# Step 1: Remove Punctuation & Symbols

clean_text = paragraph

# %%
# Step 2: Remove Stopwords

filtered_text = clean_text

# %%
# Step 3:  Remove Frequent Words

final_filtered_text = filtered_text

# %%
# Step 4: Remove Digits

no_digits_text = final_filtered_text

# %%
# Step 5: Convert to Lowercase

lower_text = no_digits_text

# %%
# Step 6: Tokenize(split) the Text
tokens = no_digits_text.split()

print(tokens)
# Out:
# ['Hey!', '@Ali123,', 'how', 'r', 'u?', 'I', 'hope', 'u', 'r', 'doing', 'well', 'in', 'ur', 'exams.', 'The', 'results', 'r', 'out', 'on', '25th', '&', 'everyone', 'is', 'excited!!!', 'Plz,', 'check', 'ur', 'email', '&', 'confirm', 'ur', 'attendance', 'for', 'the', 'event.', 'C', 'u', 'there!']
